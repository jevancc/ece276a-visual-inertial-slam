# %%
# %reload_ext autoreload
# %autoreload 2
import collections, itertools, math
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg
import time, sys, os
from scipy import sparse

sys.path.append('..')
from src.utils import *

# %%
filename = "./data/0022.npz"
# filename = "./data/0027.npz"
# filename = "./data/0034.npz"
t, features, linear_velocity, rotational_velocity, K, b, cam_T_imu = load_data(filename)
# features = features[:, ::3, :]

# %%
from src.mapping import EKFLandmarkMapping

ekf = EKFLandmarkMapping(
    n_landmarks=features.shape[1],
    robot_cam_T_imu=cam_T_imu,
    robot_cam_intrinsic_calib=K,
    robot_cam_baseline=b,
    observation_noise_covariance= 100 * np.eye(4),
    prior_landmark_covariance= 5e-3 * np.eye(3),
    process_noise_covariance= 1e-3 * np.eye(6)
)


u = np.vstack([linear_velocity, rotational_velocity])
T = linear_velocity.shape[-1]
pose = []

for i in range(1, T):
    ekf.predict(u[:, i], (t[0, i] - t[0, i-1]))
    start = time.time()
    ekf.update(features[:, :, i])
    pose.append(np.linalg.inv(ekf.xU))
    end = time.time()

    if i % 1 == 0:
        print(f'------------ {i} ----------------------')
        print('INITIALIZED LANDMARK:::', ekf.n_initialized)
        print('TIME COST::', round(end - start, 2))

pose = np.stack(pose, -1) if isinstance(pose, list) else pose
visualize_trajectory_2d(pose, ekf.xm, show_ori=True)
# Out:
# ------------ 1 ----------------------
# INITIALIZED LANDMARK::: 49
# TIME COST:: 0.0
# ------------ 2 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.02
# ------------ 3 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.02
# ------------ 4 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.02
# ------------ 5 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.02
# ------------ 6 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 7 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 8 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 9 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.02
# ------------ 10 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 11 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 12 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 13 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 14 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 15 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 16 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 17 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 18 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 19 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 20 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 21 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 22 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 23 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 24 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 25 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 26 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 27 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 28 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 29 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 30 ----------------------
# INITIALIZED LANDMARK::: 103
# TIME COST:: 0.01
# ------------ 31 ----------------------
# INITIALIZED LANDMARK::: 142
# TIME COST:: 0.02
# ------------ 32 ----------------------
# INITIALIZED LANDMARK::: 142
# TIME COST:: 0.02
# ------------ 33 ----------------------
# INITIALIZED LANDMARK::: 142
# TIME COST:: 0.01
# ------------ 34 ----------------------
# INITIALIZED LANDMARK::: 142
# TIME COST:: 0.01
# ------------ 35 ----------------------
# INITIALIZED LANDMARK::: 142
# TIME COST:: 0.01
# ------------ 36 ----------------------
# INITIALIZED LANDMARK::: 142
# TIME COST:: 0.02
# ------------ 37 ----------------------
# INITIALIZED LANDMARK::: 142
# TIME COST:: 0.01
# ------------ 38 ----------------------
# INITIALIZED LANDMARK::: 142
# TIME COST:: 0.01
# ------------ 39 ----------------------
# INITIALIZED LANDMARK::: 182
# TIME COST:: 0.03
# ------------ 40 ----------------------
# INITIALIZED LANDMARK::: 182
# TIME COST:: 0.02
# ------------ 41 ----------------------
# INITIALIZED LANDMARK::: 182
# TIME COST:: 0.02
# ------------ 42 ----------------------
# INITIALIZED LANDMARK::: 182
# TIME COST:: 0.02
# ------------ 43 ----------------------
# INITIALIZED LANDMARK::: 182
# TIME COST:: 0.02
# ------------ 44 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.05
# ------------ 45 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.05
# ------------ 46 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.03
# ------------ 47 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.04
# ------------ 48 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.03
# ------------ 49 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.03
# ------------ 50 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.03
# ------------ 51 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.03
# ------------ 52 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.02
# ------------ 53 ----------------------
# INITIALIZED LANDMARK::: 224
# TIME COST:: 0.02
# ------------ 54 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.06
# ------------ 55 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.05
# ------------ 56 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.05
# ------------ 57 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.06
# ------------ 58 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.06
# ------------ 59 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.04
# ------------ 60 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.05
# ------------ 61 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.04
# ------------ 62 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.05
# ------------ 63 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.04
# ------------ 64 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.04
# ------------ 65 ----------------------
# INITIALIZED LANDMARK::: 274
# TIME COST:: 0.04
# ------------ 66 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.08
# ------------ 67 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.08
# ------------ 68 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.06
# ------------ 69 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.06
# ------------ 70 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.07
# ------------ 71 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.07
# ------------ 72 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.06
# ------------ 73 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.05
# ------------ 74 ----------------------
# INITIALIZED LANDMARK::: 317
# TIME COST:: 0.05
# ------------ 75 ----------------------
# INITIALIZED LANDMARK::: 341
# TIME COST:: 0.07
# ------------ 76 ----------------------
# INITIALIZED LANDMARK::: 341
# TIME COST:: 0.06
# ------------ 77 ----------------------
# INITIALIZED LANDMARK::: 341
# TIME COST:: 0.06
# ------------ 78 ----------------------
# INITIALIZED LANDMARK::: 341
# TIME COST:: 0.06
# ------------ 79 ----------------------
# INITIALIZED LANDMARK::: 369
# TIME COST:: 0.11
# ------------ 80 ----------------------
# INITIALIZED LANDMARK::: 369
# TIME COST:: 0.11
# ------------ 81 ----------------------
# INITIALIZED LANDMARK::: 369
# TIME COST:: 0.09
# ------------ 82 ----------------------
# INITIALIZED LANDMARK::: 369
# TIME COST:: 0.07
# ------------ 83 ----------------------
# INITIALIZED LANDMARK::: 369
# TIME COST:: 0.08
# ------------ 84 ----------------------
# INITIALIZED LANDMARK::: 369
# TIME COST:: 0.06
# ------------ 85 ----------------------
# INITIALIZED LANDMARK::: 395
# TIME COST:: 0.09
# ------------ 86 ----------------------
# INITIALIZED LANDMARK::: 395
# TIME COST:: 0.1
# ------------ 87 ----------------------
# INITIALIZED LANDMARK::: 395
# TIME COST:: 0.07
# ------------ 88 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.1
# ------------ 89 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.12
# ------------ 90 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.12
# ------------ 91 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.1
# ------------ 92 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.11
# ------------ 93 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.1
# ------------ 94 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.12
# ------------ 95 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.1
# ------------ 96 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.1
# ------------ 97 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.1
# ------------ 98 ----------------------
# INITIALIZED LANDMARK::: 427
# TIME COST:: 0.13
# ------------ 99 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.21
# ------------ 100 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.2
# ------------ 101 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.19
# ------------ 102 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.18
# ------------ 103 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.19
# ------------ 104 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.17
# ------------ 105 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.17
# ------------ 106 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.16
# ------------ 107 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.18
# ------------ 108 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.16
# ------------ 109 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.16
# ------------ 110 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.15
# ------------ 111 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.15
# ------------ 112 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.14
# ------------ 113 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.15
# ------------ 114 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.17
# ------------ 115 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.16
# ------------ 116 ----------------------
# INITIALIZED LANDMARK::: 489
# TIME COST:: 0.13
# ------------ 117 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.24
# ------------ 118 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.28
# ------------ 119 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.25
# ------------ 120 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.25
# ------------ 121 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.25
# ------------ 122 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.23
# ------------ 123 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.22
# ------------ 124 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.21
# ------------ 125 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.23
# ------------ 126 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.2
# ------------ 127 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.2
# ------------ 128 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.2
# ------------ 129 ----------------------
# INITIALIZED LANDMARK::: 551
# TIME COST:: 0.2
# ------------ 130 ----------------------
# INITIALIZED LANDMARK::: 601
# TIME COST:: 0
----------------------
# INITIALIZED LANDMARK::: 2983
# TIME COST:: 28.02
# ------------ 751 ----------------------
# INITIALIZED LANDMARK::: 2983
# TIME COST:: 29.1
# ------------ 752 ----------------------
# INITIALIZED LANDMARK::: 2983
# TIME COST:: 28.06
# ------------ 753 ----------------------
# INITIALIZED LANDMARK::: 2983
# TIME COST:: 27.71
# ------------ 754 ----------------------
# INITIALIZED LANDMARK::: 2983
# TIME COST:: 29.44
# ------------ 755 ----------------------
# INITIALIZED LANDMARK::: 2983
# TIME COST:: 29.19
# ------------ 756 ----------------------
# INITIALIZED LANDMARK::: 2983
# TIME COST:: 27.29
# ------------ 757 ----------------------
# INITIALIZED LANDMARK::: 2983
# TIME COST:: 27.45
# ------------ 758 ----------------------
# INITIALIZED LANDMARK::: 3031
# TIME COST:: 30.19
# ------------ 759 ----------------------
# INITIALIZED LANDMARK::: 3031
# TIME COST:: 29.55
# ------------ 760 ----------------------
# INITIALIZED LANDMARK::: 3031
# TIME COST:: 31.38
# ------------ 761 ----------------------
# INITIALIZED LANDMARK::: 3031
# TIME COST:: 34.8
# ------------ 762 ----------------------
# INITIALIZED LANDMARK::: 3031
# TIME COST:: 30.58
# ------------ 763 ----------------------
# INITIALIZED LANDMARK::: 3031
# TIME COST:: 34.99
# ------------ 764 ----------------------
# INITIALIZED LANDMARK::: 3062
# TIME COST:: 31.81
# ------------ 765 ----------------------
# INITIALIZED LANDMARK::: 3062
# TIME COST:: 31.67
# ------------ 766 ----------------------
# INITIALIZED LANDMARK::: 3062
# TIME COST:: 29.04
# ------------ 767 ----------------------
# INITIALIZED LANDMARK::: 3092
# TIME COST:: 30.56
# ------------ 768 ----------------------
# INITIALIZED LANDMARK::: 3092
# TIME COST:: 39.65
# ------------ 769 ----------------------
# INITIALIZED LANDMARK::: 3092
# TIME COST:: 36.62
# ------------ 770 ----------------------
# INITIALIZED LANDMARK::: 3092
# TIME COST:: 34.74
# ------------ 771 ----------------------
# INITIALIZED LANDMARK::: 3092
# TIME COST:: 36.82
# ------------ 772 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 32.78
# ------------ 773 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 34.6
# ------------ 774 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 30.65
# ------------ 775 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 26.65
# ------------ 776 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 26.91
# ------------ 777 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 28.97
# ------------ 778 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 31.86
# ------------ 779 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 49.32
# ------------ 780 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 35.8
# ------------ 781 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 32.82
# ------------ 782 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 32.48
# ------------ 783 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 30.65
# ------------ 784 ----------------------
# INITIALIZED LANDMARK::: 3136
# TIME COST:: 30.0
# ------------ 785 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 33.49
# ------------ 786 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 32.81
# ------------ 787 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 33.31
# ------------ 788 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 35.81
# ------------ 789 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 33.16
# ------------ 790 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 32.51
# ------------ 791 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 32.05
# ------------ 792 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 33.11
# ------------ 793 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 32.22
# ------------ 794 ----------------------
# INITIALIZED LANDMARK::: 3181
# TIME COST:: 29.58
# ------------ 795 ----------------------
# INITIALIZED LANDMARK::: 3220
# TIME COST:: 29.13
# ------------ 796 ----------------------
# INITIALIZED LANDMARK::: 3220
# TIME COST:: 29.16
# ------------ 797 ----------------------
# INITIALIZED LANDMARK::: 3220
# TIME COST:: 35.15
# ------------ 798 ----------------------
# INITIALIZED LANDMARK::: 3220
# TIME COST:: 29.35
# ------------ 799 ----------------------
# INITIALIZED LANDMARK::: 3220
# TIME COST:: 28.94
# (<Figure size 864x864 with 1 Axes>,
#  <matplotlib.axes._subplots.AxesSubplot at 0x1d819e4ed08>)
